# %%
import pandas as pd
import numpy as np
d = pd.read_csv("hw3index.csv")

# %%
d.shape
d.head()
t = list(d)
dclean = d.drop(columns=['Unnamed: 1'])
np.sum(dclean.isna())
print(dclean.shape)
dclean.to_csv("cleanIndex.csv",index=False)
dclean
# Out:
# (756, 487)
#      ('Close', 'SPX')  ('Close', 'A')  ('Close', 'AAL')  ('Close', 'AAP')  \
# 0          146.059998       29.957081         13.980000         72.489998
# 1          145.729996       30.064377         13.660000         72.489998
# 2          146.369995       30.658083         14.730000         73.620003
# 3          145.970001       30.436338         14.840000         73.370003
# 4          145.550003       30.193132         15.160000         72.169998
# 5          145.919998       31.008583         15.130000         72.389999
# 6          147.080002       31.237482         15.140000         71.760002
# 7          147.070007       31.065809         14.780000         72.290001
# 8          146.970001       31.144491         14.670000         72.580002
# 9          147.070007       30.929899         14.310000         73.639999
# 10         147.050003       30.793991         14.630000         73.360001
# ...
