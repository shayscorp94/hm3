# %%
import pandas as pd
import numpy as np
d = pd.read_csv("hw3index.csv")

# %%
d.shape
d.head()
# t = list(d)
# dclean = d.drop(columns=['Unnamed: 1'])
# np.sum(dclean.isna())
# print(dclean.shape)
# dclean.to_csv("cleanIndex.csv",index=False)
# dclean
# Out:
#    ('Close', 'SPX')  Unnamed: 1  ('Close', 'A')  ('Close', 'AAL')  \
# 0        146.059998         NaN       29.957081             13.98
# 1        145.729996         NaN       30.064377             13.66
# 2        146.369995         NaN       30.658083             14.73
# 3        145.970001         NaN       30.436338             14.84
# 4        145.550003         NaN       30.193132             15.16
#
#    ('Close', 'AAP')  ('Close', 'AAPL')  ('Close', 'ABBV')  ('Close', 'ABC')  \
# 0         72.489998          78.432854          35.119999         43.490002
# 1         72.489998          77.442856          34.830002         43.400002
# 2         73.620003          75.285713          34.389999         43.689999
# 3         73.370003          74.842857          34.459999         43.830002
# 4         72.169998          75.044289          33.709999         43.770000
#
#    ('Close', 'ABMD')  ('Close', 'ABT')  ...  ('Close', 'XEL')  \
# ...
